# %% [markdown]
# <a href="https://colab.research.google.com/github/likeshd/datascience_case_study/blob/main/text_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob import TextBlob
import spacy
from collections import defaultdict
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text = pd.read_csv("/content/articles.csv", encoding='latin-1')
print(text.head(5))
# Out:
#                                              Article  \
# 0  Data analysis is the process of inspecting and...
# 1  The performance of a machine learning algorith...
# 2  You must have seen the news divided into categ...
# 3  When there are only two classes in a classific...
# 4  The Multinomial Naive Bayes is one of the vari...
#
#                                                Title
# 0                  Best Books to Learn Data Analysis
# 1         Assumptions of Machine Learning Algorithms
# 2          News Classification with Machine Learning
# 3  Multiclass Classification Algorithms in Machin...
# 4        Multinomial Naive Bayes in Machine Learning

# %%
text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Article  34 non-null     object
#  1   Title    34 non-null     object
# dtypes: object(2)
# memory usage: 672.0+ bytes

# %%
# Combine all titles into a single string
titles_text = ' '.join(text['Title'])
titles_text
# Out:
# 'Best Books to Learn Data Analysis Assumptions of Machine Learning Algorithms News Classification with Machine Learning Multiclass Classification Algorithms in Machine Learning Multinomial Naive Bayes in Machine Learning News Classification with Machine Learning Best Books to Learn NLP Send Instagram Messages using Python Pfizer Vaccine Sentiment Analysis using Python Squid Game Sentiment Analysis using Python Best Books to Learn Computer Vision Best Resources to Learn Python Best Python Frameworks to Build APIs Voice Recorder using Python Language Detection with Machine Learning Multilayer Perceptron in Machine Learning Types of Neural Networks Clustering Algorithms in Machine Learning For Loop Over Keys and Values in a Python Dictionary Health Insurance Premium Prediction with Machine Learning Mean Shift Clustering in Machine Learning BIRCH Clustering in Machine Learning Agglomerative Clustering in Machine Learning DBSCAN Clustering in Machine Learning K-Means Clustering in Machine Learning Animated Scatter Plot using Python Tata Motors Stock Price Prediction with Machine Learning Apple Stock Price Prediction with Machine Learning Best Books to Learn Deep Learning Applications of Deep Learning Introduction to Recommendation Systems Use Cases of Different Machine Learning Algorithms Naive Bayes Algorithm in Machine Learning Swap Items of a Python List'

# %%
# Create a WordCloud object
wordcloud = WordCloud(width=1000, height=500, background_color='white').generate(titles_text)
wordcloud

# %%
# Plot the Word Cloud
fig = px.imshow(wordcloud, title='Word Cloud of Titles')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7d90b991-95b0-45f0-be0b-01f62eeba011" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d90b991-95b0-45f0-be0b-01f62eeba011")) {                    Plotly.newPlot(                        "7d90b991-95b0-45f0-be0b-01f62eeba011",                        [{"name":"0","source":"...\u002fXLjsbS7JJSQQYL8f\u002ftidmb3bHHe7v51nnnkQDMOAhISEhISEhISEhKR\u002fQyEaSEhISEhISEhISEj6H6RwJyEhISEhISEhIXkEIIU7CQkJCQkJCQkJySMAKdxJSEieCHaciR31+m8X4nOJjvujj16WhISEhISkPTSigYSEhKS\u002fsvdq0k9Hbnk6Wh\u002f\u002fcjXRBwAAf1+I\u002f+3kHU8Hq+NfrSG4bmeUKFSauznlM4YGEFz3Qx+9LAlJP+ffXbeOHoh76\u002f1ZE6cEE33tEInke3dHx8cVNtZLMAyzsOT4Bzh98e1iBOl5JAnJkwkp3ElISB4Zpgz2\u002f\
QBDAM9kUl\u002fXTk1tm47FVTB\u002fu6mLgxk5D0EXOeirh1PScro0IkkltYcPTGRUuHlZc2ikTyxLvFDfVi4yOM4PNZfD7L09uusqKppKje1o4fGOxi8BpesFuRenb+fu3QvlgEAVs7gZ2DfW11S9SlzJvXcj78bN7YCYGEYGGjpKlJ+tbLe2qrW9w9bN08bKsrm5Lii3nvz8KHdes1y0obtvx44ezJZAtLjpuHTUO9uLiw7o\u002ff6ooL6977ZK4+RiZTqdVaN3cbCwtOWkoZk0kbOsIX\u002fyIUSi+UADmyLUKsXNOaK6Jqstf5ESuXGpSSrJYqAJh+38L95QETXx4wkWgleRiQwp2kQwYd\u002fFmiVhl22TS6A5s32N51hX94uJ0zLvDxp1AkTG2sXuQziOggeRhMjvD78fDNpPxKsVwp4LRWm1xPLQSAqab6yZhJo0gGAH4utvgKHAcr3rKJ4W1B3aSyoeVsbDYFQQyqHQCYdNqGJeOzSuvSiqqP3kpfPTUSf8iisSGLxrYORiMIrJg8+PSdrMJqYWJ+JSncSR4kgcEuCAXBdFheTs3Q4a1J9ynTWy+DGz8\u002fcSMquy3aGDt7wWffLNRvHzkQ9+e2qMBgF4MFj\u002fmReq5eyji0L9bRyfLjL+cHBDkDgE6HHd4fu2vH9c3fnB4Q6OzgaIGP12p1H2845Ovn+Mv21VbWXABQq7XJCSX2DgJDTHdfs7Kiqbqq+Y0NM2bNi9A\u002fYB87dPeP365euZixeNlwfZI+NNwjNNwDADLTK956eQ9fwO7kj7ofpjkPTGuuuFab0164X6vNwQDz4dv58IljESSPLqRwJ+kCBw6PRaXpMKhXSEslzaWS5uNFGe+Gj3t50BPUSWNPbtLligJSuPcT7Cx5ob7OKQVVt9NLZg0PBAC1RhubVQoAU4zrZLpFqI8zBUFupRf\u002ffSH+6Qlh+ER4j7mdUaLDsBBvJ4NqNzB7eGBaUfW1lEKCcJ85jJje83WxLawWCsVygp2EpE9hsugCPlskkrc0yYi+hwSmw\ ...

# %%
# Sentiment Analysis
text['Sentiment'] = text['Article'].apply(lambda x: TextBlob(x).sentiment.polarity)
text
# Out:
#                                               Article  \
# 0   Data analysis is the process of inspecting and...
# 1   The performance of a machine learning algorith...
# 2   You must have seen the news divided into categ...
# 3   When there are only two classes in a classific...
# 4   The Multinomial Naive Bayes is one of the vari...
# 5   You must have seen the news divided into categ...
# 6   Natural language processing or NLP is a subfie...
# 7   By using a third-party application or API to m...
# 8   Twitter is one of the most popular social medi...
# 9   The squid game is currently one of the most tr...
# 10  Computer Vision is one of the fields of Artifi...
# 11  Python is one of the most popular programming ...
# 12  API stands for Application Programming Interfa...
# 13  A voice recorder is found in every smartphone ...
# 14  Language detection is a natural language proce...
# 15  A Multilayer Perceptron or MLP is one of the s...
# 16  A neural network is a subset of machine learni...
# 17  Clustering is the task of identifying similar ...
# 18  Dictionaries are one of the most useful data s...
# 19  Health Insurance is a type of insurance that c...
# 20  The mean shift algorithm is a nonparametric cl...
# 21  The BIRCH is a Clustering algorithm in machine...
# 22  Agglomerative clustering is based on hierarchi...
# 23  DBSCAN stands for Density-Based Spatial Cluste...
# 24  The K-Means Clustering is a clustering algorit...
# 25  A scatter plot is one of the most useful ways ...
# 26  Recently, we have seen an increase of more tha...
# 27  Apple has just announced the date of its Septe...
# 28  Deep learning is a subset of machine learning ...
# 29  Many machine learning algorithms can be used t...
# 30  Almost every app or website you visit today sh...
# 31  There are so many algorithms in machine learni...
# 32  In machine learning, the Naive Bayes algorithm...
# 33  Swapping elements of a Python list is very sim...
#
#                                                 Title  Sentiment
# 0                   Best Books to Learn Data Analysis   0.666667
# 1          Assumptions of Machine Learning Algorithms   0.020833
# 2           News Classification with Machine Learning   0.600000
# 3   Multiclass Classification Algorithms in Machin...   0.625000
# 4         Multinomial Naive Bayes in Machine Learning  -0.101429
# 5           News Classification with Machine Learning   0.600000
# 6                             Best Books to Learn NLP   0.283333
# 7                Send Instagram Messages using Python   0.050000
# 8      Pfizer Vaccine Sentiment Analysis using Python   0.406667
# 9          Squid Game Sentiment Analysis using Python  -0.108333
# 10                Best Books to Learn Computer Vision   0.346875
# 11                     Best Resources to Learn Python   0.580000
# 12               Best Python Frameworks to Build APIs   0.479167
# 13                        Voice Recorder using Python   0.200000
# 14           Language Detection with Machine Learning   0.016667
# 15          Multilayer Perceptron in Machine Learning   0.000000
# 16                           Types of Neural Networks  -0.075000
# 17          Clustering Algorithms in Machine Learning   0.000000
# 18  For Loop Over Keys and Values in a Python Dict...   0.150000
# 19  Health Insurance Premium Prediction with Machi...   0.083333
# 20          Mean Shift Clustering in Machine Learning  -0.234375
# 21               BIRCH Clustering in Machine Learning   0.000000
# 22       Agglomerative Clustering in Machine Learning   0.157692
# 23              DBSCAN Clustering in Machine Learning  -0.800000
# 24             K-Means Clustering in Machine Learning   0.091111
# 25                 Animated Scatter Plot using Python   0.400000
# 26  Tata Motors Stock Price Prediction with Machin...   0.175000
# 27  Apple Stock Price Prediction with Machine Lear...   0.245455
# 28                  Best Books to Learn Deep Learning   0.118929
# 29                      Applications of Deep Learning   0.089796
# 30             Introduction to Recommendation Systems   0.270000
# 31  Use Cases of Different Machine Learning Algori...   0.288571
# 32          Naive Bayes Algorithm in Machine Learning  -0.181250
# 33                        Swap Items of a Python List   0.000000

# %%
# Sentiment Distribution
fig = px.histogram(text, x='Sentiment', title='Sentiment Distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0802ae67-be47-4fec-8bc1-885316187738" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0802ae67-be47-4fec-8bc1-885316187738")) {                    Plotly.newPlot(                        "0802ae67-be47-4fec-8bc1-885316187738",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sentiment=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0.6666666666666666,0.02083333333333333,0.6,0.625,-0.10142857142857142,0.6,0.2833333333333333,0.05,0.40666666666666673,-0.10833333333333334,0.346875,0.5800000000000001,0.4791666666666667,0.2,0.016666666666666653,0.0,-0.075,0.0,0.15,0.08333333333333333,-0.234375,0.0,0.1576923076923077,-0.8,0.0911111111111111,0.4,0.175,0.24545454545454545,0.11892857142857145,0.08979591836734693,0.26999999999999996,0.2885714285714286,-0.18125,0.0],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":" ...

# %%
# NER
def extract_named_entities(text):
    doc = nlp(text)
    entities = defaultdict(list)
    for ent in doc.ents:
        entities[ent.label_].append(ent.text)
    return dict(entities)

# %%
text['Named_Entities'] = text['Article'].apply(extract_named_entities)
text['Named_Entities'].head(10)
# Out:
# 0                                  {'DATE': ['today']}
# 1                                                   {}
# 2                                                   {}
# 3          {'CARDINAL': ['only two', 'more than two']}
# 4    {'ORG': ['The Multinomial Naive Bayes', 'Naive...
# 5                                                   {}
# 6    {'ORG': ['NLP', 'NLP', 'NLP', 'NLP'], 'CARDINA...
# 7    {'ORDINAL': ['third'], 'ORG': ['API', 'Instagr...
# 8    {'PRODUCT': ['Twitter', 'Twitter'], 'CARDINAL'...
# 9            {'ORG': ['NetFlix'], 'CARDINAL': ['One']}
# Name: Named_Entities, dtype: object

# %%
# Visualize NER
entity_counts = Counter(entity for entities in text['Named_Entities'] for entity in entities)
entity_df = pd.DataFrame.from_dict(entity_counts, orient='index').reset_index()
entity_df.columns = ['Entity', 'Count']

fig = px.bar(entity_df.head(10), x='Entity', y='Count', title='Top 10 Named Entities')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5429f15b-f9a2-4321-bf08-6a7f7d8ac430" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5429f15b-f9a2-4321-bf08-6a7f7d8ac430")) {                    Plotly.newPlot(                        "5429f15b-f9a2-4321-bf08-6a7f7d8ac430",                        [{"alignmentgroup":"True","hovertemplate":"Entity=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["DATE","CARDINAL","ORG","ORDINAL","LOC","PRODUCT","PERSON","GPE","FAC"],"xaxis":"x","y":[8,9,20,1,1,1,3,4,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker ...

# %%
# Topic Modeling
vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=1000, stop_words='english')
tf = vectorizer.fit_transform(text['Article'])
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_topic_matrix = lda_model.fit_transform(tf)

# %%
# Visualize topics
topic_names = ["Topic " + str(i) for i in range(lda_model.n_components)]
text['Dominant_Topic'] = [topic_names[i] for i in lda_topic_matrix.argmax(axis=1)]
text['Dominant_Topic']
# Out:
# 0     Topic 1
# 1     Topic 0
# 2     Topic 1
# 3     Topic 3
# 4     Topic 4
# 5     Topic 1
# 6     Topic 0
# 7     Topic 1
# 8     Topic 2
# 9     Topic 2
# 10    Topic 1
# 11    Topic 1
# 12    Topic 1
# 13    Topic 1
# 14    Topic 1
# 15    Topic 1
# 16    Topic 1
# 17    Topic 4
# 18    Topic 1
# 19    Topic 2
# 20    Topic 3
# 21    Topic 3
# 22    Topic 3
# 23    Topic 3
# 24    Topic 3
# 25    Topic 1
# 26    Topic 1
# 27    Topic 1
# 28    Topic 0
# 29    Topic 0
# 30    Topic 1
# 31    Topic 1
# 32    Topic 4
# 33    Topic 1
# Name: Dominant_Topic, dtype: object

# %%
fig = px.bar(text['Dominant_Topic'].value_counts().reset_index(), x='index', y='Dominant_Topic', title='Topic Distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="94a00e84-95de-4d0b-a9c2-ea8faec75417" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94a00e84-95de-4d0b-a9c2-ea8faec75417")) {                    Plotly.newPlot(                        "94a00e84-95de-4d0b-a9c2-ea8faec75417",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}\u003cbr\u003eDominant_Topic=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Topic 1","Topic 3","Topic 0","Topic 4","Topic 2"],"xaxis":"x","y":[18,6,4,3,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outli ...
